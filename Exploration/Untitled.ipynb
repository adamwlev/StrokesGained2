# %%
import pandas as pd
import gc
import matplotlib.pyplot as plt
# %matplotlib inline
pd.options.display.max_columns = 999

# %%
new_data.shape
# Out:
# (1091905, 47)

# %%
raw_data.shape
# Out:
# (1255867, 39)

# %%
new_data = pd.read_csv('ProcessingPipeline/2003.csv')

# %%
id_cols = ['Permanent_Tournament_#','Player_#','Round','Hole']

# %%
new_data['Stroke'] = new_data.groupby(id_cols)['Penalty_Shots'].cumsum() + new_data.Real_Shots

# %%
res = (new_data.groupby(id_cols)['Hole_Score'].max()<new_data.groupby(id_cols)['Stroke'].max())
res[res==True]
# Out:
# Series([], dtype: bool)

# %%
(new_data.Start_Z_Coordinate==0).sum()
# Out:
# 0

# %%
new_data[['Start_X_Coordinate','Start_Y_Coordinate','Start_Z_Coordinate','Shot',
    'End_X_Coordinate','End_Y_Coordinate','End_Z_Coordinate']]
# Out:
#          Start_X_Coordinate  Start_Y_Coordinate  Start_Z_Coordinate  Shot  \
# 0               6818.287997         6977.385100                 NaN     1
# 1               7554.588000         6669.062000            2454.659     2
# 2               7839.173000         6353.067000            2458.339     3
# 3               8413.589521         5978.145375                 NaN     1
# 4               8504.246000         6839.635000            2460.686     2
# 5               8604.083000         7475.441000            2466.759     3
# 6               8644.831000         7538.393000            2472.085     4
# 7               8658.222000         7574.163000            2473.135     5
# 8               8683.931654         7743.062776                 NaN     1
# 9               9385.075000         7910.783000            2471.259     2
# 10              9653.659000         8185.101000            2476.464     3
# 11              9636.093000         8178.507000            2476.048     4
# ...

# %%
new_data['Stroke'] = new_data.groupby(id_cols)['Penalty_Shots'].cumsum() + new_data['Real_Shots']

# %%
(new_data.groupby(id_cols).Hole_Score.max()==new_data.groupby(id_cols)['Stroke'].max()).mean()
# Out:
# 0.99891993865251549

# %%
new_data.head()
# Out:
#   Tour_Code Tour_Description  Year  Tourn.#  Player_#  Course_#  \
# 0         R         PGA TOUR  2003       80      1014       101
# 1         R         PGA TOUR  2003       80      1014       101
# 2         R         PGA TOUR  2003       80      1014       101
# 3         R         PGA TOUR  2003       80      1014       101
# 4         R         PGA TOUR  2003       80      1014       101
#
#    Permanent_Tournament_# Player_First_Name Player_Last_Name  Round  \
# 0                       1            Fulton            Allem      1
# 1                       1            Fulton            Allem      1
# 2                       1            Fulton            Allem      1
# 3                       1            Fulton            Allem      1
# 4                       1            Fulton            Allem      1
#
#               Tournament_Name         Course_Name  Hole  Hole_Score  \
# 0  Chrysler Classic of Tucson  Tucson National GC     1           3
# ...

# %%
data = new_data

# %%
hole = data[(data['Permanent_Tournament_#']==1) & (data.Round==1) & (data.Hole==18)]
hole_x, hole_y =  hole[hole.Strokes_from_starting_location==1].iloc[0][['End_X_Coordinate','End_Y_Coordinate']]
sub = hole[(hole.Distance_from_hole<70) & (hole['From_Location(Scorer)']!='Green')]
x, y, g = sub.Start_X_Coordinate, sub.Start_Y_Coordinate, sub.Green_to_work_with
fig, ax = plt.subplots(1, 1, figsize=(15,15))
plt.scatter(x,y,s=100);
green = hole[hole['From_Location(Scorer)']=='Green']
green_x, green_y = green.Start_X_Coordinate, green.Start_Y_Coordinate
plt.scatter(green_x,green_y,c='r',alpha=.7)
for x_,y_,g_ in zip(x,y,g):
    plt.text(x_,y_+3,round(g_,3),horizontalalignment='center')

# %%
hole = data[(data['Permanent_Tournament_#']==1) & (data.Round==1) & (data.Hole==18)]
hole_x, hole_y =  hole[hole.Strokes_from_starting_location==1].iloc[0][['End_X_Coordinate','End_Y_Coordinate']]
sub = hole[(hole.Distance_from_hole<70) & (hole['From_Location(Scorer)']!='Green')]
x, y, g = sub.Start_X_Coordinate, sub.Start_Y_Coordinate, sub.Green_to_work_with
fig, ax = plt.subplots(1, 1, figsize=(15,15))
plt.scatter(x,y);
for x_,y_,g_ in zip(x,y,g):
    plt.text(x_,y_+3,round(g_,3),horizontalalignment='center')

# %%
grouped = data.groupby(['Course_#','Round','Hole'])

# %%
from math import atan2,radians,pi
import numpy as np

# %%
angle=-3

# %%
def wrap(angle):
    if angle > pi:
        return angle - 2*pi
    elif angle < -pi:
        return angle + 2*pi
    else:
        return angle

# %%
# Out:
# (3, 2.1273353740028353, -2.4105206811824216)

# %%
angle,wrap(angle-radians(50)),wrap(angle+radians(50))
# Out:
# (-3, 2.4105206811824216, -2.1273353740028353)

# %%
# Out:
# 0.8726646259971648

# %%
def get_sub(df,angle,slack):
    return df[(df.angle>angle-slack) & (df.angle<angle+slack)]

# %%
for i,((course,round,hole),df) in enumerate(grouped):
    if i>1:
        break
    df = df.copy()
    hole_x, hole_y = df[df.Strokes_from_starting_location==1].iloc[0][['End_X_Coordinate','End_Y_Coordinate']]
    df.Start_X_Coordinate = df.Start_X_Coordinate - hole_x
    df.Start_Y_Coordinate = df.Start_Y_Coordinate - hole_y
    df.End_X_Coordinate = df.End_X_Coordinate - hole_x
    df.End_Y_Coordinate = df.End_Y_Coordinate - hole_y
    non_green = df[df.Cat!='Green']
    green = df[df.Cat=='Green']
    green.insert(len(green.columns),'angle',[atan2(y,x) for x,y in zip(green.Start_X_Coordinate,green.Start_Y_Coordinate)])
    work_with = []
    for x,y in zip(non_green.Start_X_Coordinate,non_green.Start_Y_Coordinate):
        angle = atan2(y,x)
        slack = 23
        sub = get_sub(green,angle,radians(slack))
        c = 0
        while len(sub)==0:
            c += 1
            slack += .5
            if c==130:
                break
            sub = get_sub(green,angle,radians(slack))
        if c==130:
            work_with.append(np.nan)
        else:
            work_with.append(sub.Distance_from_hole.max())
    assert np.all(data[(data['Course_#']==course) & (data.Round==round) & (data.Hole==hole) & (data.Cat!='Green')].index==non_green.index)
    data.loc[non_green.index,'Green_to_work_with'] = work_with

# %%
green.angle.describe()
# Out:
# count    136.000000
# mean      -0.873012
# std        1.452186
# min       -3.131507
# 25%       -1.805188
# 50%       -1.200109
# 75%       -0.355558
# max        3.138414
# Name: angle, dtype: float64
