# %%
import pandas as pd
import gc

# %%
new_data = pd.read_csv('2003.csv')
raw_data = pd.read_csv('data/rawdata/2003.txt',sep=';')
# Out:
# /Users/adamlevin/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
new_data.shape
# Out:
# (1243093, 45)

# %%
raw_data.shape
# Out:
# (1255867, 39)

# %%
new_data.head(30)
# Out:
#    Tour_Code Tour_Description  Year  Tourn.#  Player_#  Course_#  \
# 0          R         PGA TOUR  2003       80      1014       101
# 1          R         PGA TOUR  2003       80      1014       101
# 2          R         PGA TOUR  2003       80      1014       101
# 3          R         PGA TOUR  2003       80      1014       101
# 4          R         PGA TOUR  2003       80      1014       101
# 5          R         PGA TOUR  2003       80      1014       101
# 6          R         PGA TOUR  2003       80      1014       101
# 7          R         PGA TOUR  2003       80      1014       101
# 8          R         PGA TOUR  2003       80      1014       101
# 9          R         PGA TOUR  2003       80      1014       101
# 10         R         PGA TOUR  2003       80      1014       101
# 11         R         PGA TOUR  2003       80      1014       101
# 12         R         PGA TOUR  2003       80      1014       101
# ...

# %%
new_data = pd.read_csv('2003.csv')

# %%
reload(impute_locations)
# Out:
# <module 'impute_locations' from 'impute_locations.py'>

# %%
df[['Start_X_Coordinate','Start_Y_Coordinate','Start_Z_Coordinate','Distance_to_Hole_after_the_Shot','Shot']]
# Out:
#        Start_X_Coordinate  Start_Y_Coordinate  Start_Z_Coordinate  \
# 0                   0.000               0.000               0.000
# 1                7554.588            6669.062            2454.659
# 2                7839.173            6353.067            2458.339
# 154                 0.000               0.000               0.000
# 155              7570.497            6684.786            2455.824
# 156              7810.444            6404.682            2456.381
# 157              7822.420            6347.072            2458.379
# 158              7824.929            6337.762            2458.425
# 300                 0.000               0.000               0.000
# 301              7555.609            6623.318            2455.197
# 302              7849.401            6328.315            2458.624
# 303              7819.806            6341.695            2458.358
# 445                 0.000               0.000               0.000
# ...

# %%
id_cols = ['Permanent_Tournament_#','Round','Hole']

# %%
df
# Out:
#        Tour_Code Tour_Description  Year  Tourn.#  Player_#  Course_#  \
# 97886          R         PGA TOUR  2003       60      1014         4
# 97887          R         PGA TOUR  2003       60      1014         4
# 97888          R         PGA TOUR  2003       60      1014         4
# 97889          R         PGA TOUR  2003       60      1014         4
# 97890          R         PGA TOUR  2003       60      1014         4
# 97963          R         PGA TOUR  2003       60      1098       104
# 97964          R         PGA TOUR  2003       60      1098       104
# 97965          R         PGA TOUR  2003       60      1098       104
# 97966          R         PGA TOUR  2003       60      1098       104
# 98109          R         PGA TOUR  2003       60      1132       104
# 98110          R         PGA TOUR  2003       60      1132       104
# 98111          R         PGA TOUR  2003       60      1132       104
# 98112          R         PGA TOUR  2003       60      1132       104
# ...

# %%
for u,(tup,df) in enumerate(new_data.groupby(id_cols)):
    imputer = impute_locations.Imputer(1,df)
    if len(imputer.df)==0:
        print 'Skipping', tup
        continue
    imputer.find_location(10)
# Out:
#  0 of the 144 shots removed from consideration during imputation of hole location. Final Error: 0.0550678
#  0 of the 144 shots removed from consideration during imputation of hole location. Final Error: 0.0207507
#  0 of the 144 shots removed from consideration during imputation of hole location. Final Error: 0.0204792
#  0 of the 144 shots removed from consideration during imputation of hole location. Final Error: 0.0209693
#  0 of the 144 shots removed from consideration during imputation of hole location. Final Error: 0.0228952
#  0 of the 144 shots removed from consideration during imputation of hole location. Final Error: 0.0209329
#  0 of the 144 shots removed from consideration during imputation of hole location. Final Error: 0.0216561
#  0 of the 144 shots removed from consideration during imputation of hole location. Final Error: 0.0250722
#  0 of the 144 shots removed from consideration during imputation of hole location. Final Error: 0.0217363
# ...

# %%
for u,(tup,df) in enumerate(new_data.groupby(id_cols)):
    imputer = impute_locations.Imputer(0,df)
    if len(imputer.df)==0:
        print 'Skipping', tup
        continue
    imputer.find_location(3)
# Out:
#  0 of the 144 shots removed from consideration during imputation of hole location. Final Error: 0.0212349
#  0 of the 144 shots removed from consideration during imputation of hole location. Final Error: 0.0424533
#  0 of the 144 shots removed from consideration during imputation of hole location. Final Error: 0.0300964
#  0 of the 144 shots removed from consideration during imputation of hole location. Final Error: 0.0213187
#  0 of the 144 shots removed from consideration during imputation of hole location. Final Error: 0.024912
#  0 of the 144 shots removed from consideration during imputation of hole location. Final Error: 0.0200641
#  0 of the 144 shots removed from consideration during imputation of hole location. Final Error: 0.0195925
#  0 of the 144 shots removed from consideration during imputation of hole location. Final Error: 0.0192587
#  0 of the 144 shots removed from consideration during imputation of hole location. Final Error: 0.0268934
# ...
